# %%
import pandas as pd
import re
from time import strptime
import time
from datetime import datetime

# %%
allData = pd.read_csv("LAHacks Deidentified.csv")
# Out:
# /Users/nathanwong/Downloads/yes/envs/nathan/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
allData.head()
# Out:
#             UPC   Category Name       Vendor Name  Receiving Warehouse  \
# 0  4.856800e+05  White Cabbages  Vendor  63b9d36c  Warehouse  886ecdf1
# 1  7.143000e+09      Unassigned  Vendor  ee6aa404  Warehouse  cb7cd2e2
# 2  7.143001e+09      Unassigned  Vendor  ee6aa404  Warehouse  cb7cd2e2
# 3  7.143001e+09      Unassigned  Vendor  ee6aa404  Warehouse  cb7cd2e2
# 4  7.143000e+09      Unassigned  Vendor  ee6aa404  Warehouse  cb7cd2e2
#
#     Shipping Warehouse        PO  Total Cases  Failed Cases  \
# 0  Warehouse  e5847f7c    248117          385             0
# 1  Warehouse  773064a8  50246763            5             0
# 2  Warehouse  773064a8  50246763           10             0
# 3  Warehouse  773064a8  50246763          100             0
# 4  Warehouse  773064a8  50246763            5             0
#
#              Inspector Arrival Date Shipping Date
# 0  Inspector  4bb23bf2    15-MAR-18     12-MAR-18
# 1  Inspector  c8d7555b    31-AUG-18     30-AUG-18
# ...

# %%
allData.shape
# Out:
# (227619, 11)

# %%
allData= allData[allData['Category Name'] != 'Unassigned']
allData['Month'] = [re.sub(r'[0-9]|-','',x) for x in allData['Shipping Date'].tolist()]
allData['Month'] = [strptime(x, '%b').tm_mon for x in allData['Month'].tolist()]
allData['Day'] = [int(x[0:2]) for x in allData['Shipping Date'].tolist()]
allData['Year'] = [int('20'+str(x[len(x)-2:len(x)])) for x in allData['Shipping Date'].tolist()]

allData.head()
# Out:
#              UPC                                 Category Name  \
# 0   4.856800e+05                                White Cabbages
# 5   7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 17  7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 18  7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 23  7.143000e+09  Vegetables ? Prepared/Processed (Perishable)
#
#          Vendor Name  Receiving Warehouse   Shipping Warehouse        PO  \
# 0   Vendor  63b9d36c  Warehouse  886ecdf1  Warehouse  e5847f7c    248117
# 5   Vendor  ee6aa404  Warehouse  cb7cd2e2  Warehouse  773064a8  50246763
# 17  Vendor  ee6aa404  Warehouse  cb7cd2e2  Warehouse  773064a8  50246763
# 18  Vendor  ee6aa404  Warehouse  cb7cd2e2  Warehouse  773064a8  50246763
# 23  Vendor  ee6aa404  Warehouse  cb7cd2e2  Warehouse  773064a8  50246763
#
#     Total Cases  Failed Cases            Inspector Arrival Date Shipping Date  \
# ...

# %%
allData['datetime'] = [datetime(allData['Year'].loc[x], allData['Month'].loc[x], allData['Day'].loc[x]) for x in range(len(allData))]
#allData['datetime'] = allData[['Year','Month', 'Day']].apply(datetime)
allData.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Downloads/yes/envs/nathan/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d94be9b434a2> in <module>()
# ...

# %%
type(allData['Year'].loc[0])
# Out:
# numpy.int64

# %%
t = datetime.now()
t1 = t.timetuple()
secs = time.mktime(t1)
print (secs)
print(time.asctime(time.localtime(secs)))
# Out:
# 1553921403.0
# Fri Mar 29 21:50:03 2019

# %%
test = datetime(2018, 8, 18)
test
# Out:
# datetime.datetime(2018, 8, 18, 0, 0)

# %%
allData
# Out:
#                  UPC                                 Category Name  \
# 0       4.856800e+05                                White Cabbages
# 5       7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 17      7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 18      7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 23      7.143000e+09  Vegetables ? Prepared/Processed (Perishable)
# 25      7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 26      7.143001e+09  Vegetables ? Prepared/Processed (Perishable)
# 27      7.143000e+09  Vegetables ? Prepared/Processed (Perishable)
# 40      3.338366e+09                                       Carrots
# 41      6.058061e+10  Vegetables ? Prepared/Processed (Perishable)
# 42      6.058061e+10  Vegetables ? Prepared/Processed (Perishable)
# 43      7.146402e+10  Vegetables ? Prepared/Processed (Perishable)
# 44      4.958380e+05  Vegetables ? Prepared/Processed (Perishable)
# ...
